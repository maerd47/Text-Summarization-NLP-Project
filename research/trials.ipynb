# %%
import urllib.request as request
f, h = request.urlretrieve(
                url = "https://github.com/entbappy/Branching-tutorial/summarizer-data.zip", filename = "summarizer-data.zip")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 import urllib.request as request
# ----> 2 f, h = request.urlretrieve(
#       3                 url = "https://github.com/entbappy/Branching-tutorial/summarizer-data.zip", filename = "summarizer-data.zip")
#
# File ~\anaconda3\Lib\urllib\request.py:241, in urlretrieve(url, filename, reporthook, data)
#     224 """
#     225 Retrieve a URL into a temporary location on disk.
#     226
#    (...)
#     237 data file as well as the resulting HTTPMessage object.
#     238 """
#     239 url_type, path = _splittype(url)
# --> 241 with contextlib.closing(urlopen(url, data)) as fp:
#     242     headers = fp.info()
#     244     # Just return the local path and the "headers" for file://
#     245     # URLs. No sense in performing a copy unless requested.
#
# ...

# %%
d = {"key": "value", "key1": "value1"}

# %%
d['key']
# Out:
# 'value'

# %%
d.key

# %%
pip install box

# %%
from box import ConfigBox
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from box import ConfigBox
#
# ModuleNotFoundError: No module named 'box'

# %%
d2 = ConfigBox({"key": "value", "key1": "value1"})b

# %%
d2

# %%
d2.key

# %%
def get_product(x: int, y: int) -> int:
    return x * y

# %%
get_product(x = 2, y = 4)
# Out:
# 8

# %%
get_product(x = 2, y = "4")
# Out:
# '44'

# %%
pip install ensure==1.0.2
# Out:
# ...
#   Using cached ensure-1.0.2-py2.py3-none-any.whl.metadata (10 kB)
# ...
# Using cached ensure-1.0.2-py2.py3-none-any.whl (15 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x: int, y: int) -> int:
    return x * y

# %%
get_product(x = 2, y = 4)
# Out:
# 8

# %%
get_product(x = 2, y = "4")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 get_product(x = 2, y = "4")
#
# File ~\anaconda3\Lib\site-packages\ensure\main.py:845, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     840     if not isinstance(value, templ):
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
# --> 845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
#     849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x000001A9F27C7560> does not match annotation type <class 'int'>
